# %% [markdown]
# #MERGE DATASET X

# %%
import pandas as pd

# %%
# Baca file CSV
data_awal_x = pd.read_csv('/content/data-awal-tweet.csv', delimiter=';')  # file awal
data_tambahan_x_1 = pd.read_csv('/content/data-tambahan1-tweet.csv', delimiter=',')  # file tambahan 1
data_tambahan_x_2 = pd.read_csv('/content/data-tambahan2-tweet.csv', delimiter=',')  # file tambahan 2

# %%
# Merge seluruh dataset menjadi 1
data_x = pd.concat([data_awal_x, data_tambahan_x_1,data_tambahan_x_2], ignore_index=True)

# %%
# Tampilan DataFrame hasil gabungan
data_x.head()
# Out:
#   conversation_id_str                      created_at  favorite_count  \
# 0         1,79511E+18  Mon May 27 15:23:40 +0000 2024               0
# 1         1,79504E+18  Mon May 27 10:24:21 +0000 2024               0
# 2         1,79499E+18  Mon May 27 07:18:28 +0000 2024               0
# 3         1,79491E+18  Mon May 27 04:36:40 +0000 2024               1
# 4         1,79473E+18  Sun May 26 22:53:23 +0000 2024               0
#
#                                            full_text       id_str image_url  \
# 0       Ini implikasi masih jadi presiden taun depan  1,79511E+18       NaN
# 1  Sepertinya setelah pelantikan presiden dunia m...  1,79504E+18       NaN
# 2  Menyatakan oposisi setelah pelantikan presiden...  1,79499E+18       NaN
# 3  Sampai saat ini kondisi politik dan pertumbuha...  1,79495E+18       NaN
# 4  pelantikan presiden baru kalo ada kebijakannya...  1,79486E+18       NaN
#
#   in_reply_to_screen_name lang       location  quote_count  reply_count  \
# 0                     NaN   in  Hindia Widodo            0            0
# 1                     NaN   in   Dalem Sumur             0            0
# 2                     NaN   in            NaN            0            0
# 3          DedynurPalakka   in            NaN            0            0
# 4                  jogmfs   in            NaN            0            1
#
#    retweet_count                                          tweet_url  \
# 0              0  https://x.com/und_cuckoosnest/status/179511364...
# 1              0  https://x.com/KangSuparmin/status/179503832372...
# 2              0  https://x.com/CantikSeorang/status/17949915476...
# 3              0  https://x.com/R19cakra/status/1794950828601880779
# 4              0  https://x.com/daunkaca/status/1794864436584575474
#
#    user_id_str         username
# 0  1,76091E+18  und_cuckoosnest
# 1   2556225356     KangSuparmin
# 2  1,73631E+18    CantikSeorang
# 3  1,73096E+18         R19cakra
# 4  1,24393E+18         daunkaca

# %%
data_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      1986 non-null   object
#  1   created_at               1986 non-null   object
#  2   favorite_count           1986 non-null   int64
#  3   full_text                1986 non-null   object
#  4   id_str                   1986 non-null   object
#  5   image_url                439 non-null    object
#  6   in_reply_to_screen_name  1033 non-null   object
#  7   lang                     1986 non-null   object
#  8   location                 989 non-null    object
#  9   quote_count              1986 non-null   int64
#  10  reply_count              1986 non-null   int64
#  11  retweet_count            1986 non-null   int64
#  12  tweet_url                1986 non-null   object
#  13  user_id_str              1986 non-null   object
#  14  username                 1986 non-null   object
# dtypes: int64(4), object(11)
# memory usage: 232.9+ KB

# %%
# Menyimpan dataset
data_x.to_csv('dataset_x.csv', index=False)

# %% [markdown]
# #MERGE DATASET COMMENT-YOUTUBE

# %%
# Baca file
data_awal_youtube = pd.read_excel('/content/data-awal-youtube-comments.xlsx')  # file awal

# %%
data_tambahan_youtube_1_cnn = pd.read_csv('/content/youtube-comments-CNN.csv', delimiter=',',encoding='utf-8')  # file tambahan 1
data_tambahan_youtube_2_kompascom = pd.read_csv('/content/youtube-comments-Kompas.com.csv', delimiter=',',encoding='utf-8')  # file tambahan 2
data_tambahan_youtube_3_kompastv = pd.read_csv('/content/youtube-comments-KompasTV.csv', delimiter=',',encoding='utf-8')  # file tambahan 3
data_tambahan_youtube_4_metrotv = pd.read_csv('/content/youtube-comments-MetroTV.csv', delimiter=',',encoding='utf-8')  # file tambahan 4

# %%
# Merge seluruh dataset menjadi 1
data_youtube = pd.concat([
    data_awal_youtube,
    data_tambahan_youtube_1_cnn,
    data_tambahan_youtube_2_kompascom,
    data_tambahan_youtube_3_kompastv,
    data_tambahan_youtube_4_metrotv], ignore_index=True)

# %%
data_youtube
# Out:
#                publishedAt      authorDisplayName  \
# 0     2024-04-23T22:46:35Z  @mranggenmranghen9769
# 1     2024-04-23T16:28:37Z       @user-uu5qx4lo1n
# 2     2024-04-22T13:14:02Z          @porwanti8152
# 3     2024-04-20T16:17:07Z    @endangsulastri9372
# 4     2024-04-19T12:02:11Z               @HanilNi
# ...                    ...                    ...
# 2696  2024-03-02T11:28:09Z     @ramsesnababan1071
# 2697  2024-03-02T11:24:42Z      @RahmadTour-ns9zk
# 2698  2024-03-02T11:23:57Z      @RahmadTour-ns9zk
# 2699  2024-03-02T11:23:35Z      @RahmadTour-ns9zk
# 2700  2024-03-02T11:22:42Z    @candrapurnawan8353
#
#                                             textDisplay  like_count  likeCount
# 0                               Semoga amanah ya bapak❤         0.0        NaN
# 1                                                Curang         0.0        NaN
# 2                                      Prabowo sombong😡         0.0        NaN
# 3     Saya berdoa supaya apa yg dikatakan Prabowo te...         0.0        NaN
# 4     Awas awas hati hati kata jokowi, prabowo hati ...         0.0        NaN
# ...                                                 ...         ...        ...
# 2696       Jgn banyak omong Takut salah, bukti yg perlu         NaN        0.0
# 2697                      MIMMMMMMPIIIIIII<br>😂😂😂😂😂😂😂😂😂         NaN        0.0
# 2698                                           HA HA HA         NaN        0.0
# 2699                                              😂😂😂😂😂         NaN        0.0
# 2700  Kalau Nasdem masuk pemerintah. Apa metro masih...         NaN        3.0
#
# [2701 rows x 5 columns]

# %%
data_youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2701 entries, 0 to 2700
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   publishedAt        2701 non-null   object
#  1   authorDisplayName  2701 non-null   object
#  2   textDisplay        2700 non-null   object
#  3   like_count         245 non-null    float64
#  4   likeCount          2454 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 105.6+ KB

# %%
# Menyimpan dataset
data_youtube.to_csv('dataset_youtube.csv', index=False)

# %% [markdown]
# #MERGE DATASET COMMENT-INSTAGRAM

# %%
# Baca file
data_awal_instagram = pd.read_csv('//content/data-awal-instagram-comment.csv',delimiter=';')  # file awal

# %%
data_tambahan_instagram_1_cnn = pd.read_csv('/content/instagram-cnnid.csv', delimiter=',',encoding='utf-8')  # file tambahan 1
data_tambahan_instagram_2_kompascom = pd.read_csv('/content/instagram-comment-kompascom.csv', delimiter=',',encoding='utf-8')  # file tambahan 2
data_tambahan_instagram_3_suaradotcom = pd.read_csv('/content/instagram-comment-suaradotcom.csv', delimiter=',',encoding='utf-8')  # file tambahan 3
data_tambahan_instagram_4_terasinfobkn = pd.read_csv('/content/instagram-comment-terasinfobkn.csv', delimiter=',',encoding='utf-8')  # file tambahan 4
data_tambahan_instagram_5_detikcom = pd.read_csv('/content/instagram-comment-detikcom.csv', delimiter=',',encoding='utf-8')  # file tambahan 5

# %%
# Merge seluruh dataset menjadi 1
data_instagram = pd.concat([
    data_awal_instagram,
    data_tambahan_instagram_1_cnn,
    data_tambahan_instagram_2_kompascom,
    data_tambahan_instagram_3_suaradotcom,
    data_tambahan_instagram_4_terasinfobkn,
    data_tambahan_instagram_5_detikcom], ignore_index=True)

# %%
data_instagram
# Out:
#                                       instagram_account  \
# 0                  https://www.instagram.com/sybila4239
# 1                  https://www.instagram.com/2person_30
# 2                https://www.instagram.com/ersita_megaa
# 3                  https://www.instagram.com/cannberryy
# 4             https://www.instagram.com/supriabdullah97
# ...                                                 ...
# 2409           https://www.instagram.com/riirin.gobell/
# 2410  https://www.instagram.com/ghania.entertainment...
# 2411            https://www.instagram.com/wibowo.track/
# 2412          https://www.instagram.com/iwan.muharam99/
# 2413        https://www.instagram.com/rianaldiansyah46/
#
#                      username  \
# 0                  sybila4239
# 1                  2person_30
# 2                ersita_megaa
# 3                  cannberryy
# 4             supriabdullah97
# ...                       ...
# 2409            riirin.gobell
# 2410  ghania.entertainment.wo
# 2411             wibowo.track
# 2412           iwan.muharam99
# 2413         rianaldiansyah46
#
#                                                 comment
# 0     Jangan lama2 pak, gak sabar liat bapak, jadi p...
# 1     alhamdulillah pak prabowo ????, insya allah de...
# 2                                  Bapakkk selamat yaa
# 3                                   Selamat Pak Prabowo
# 4     Mari di bulan Puasa ini berdoa semoga Pemimpin...
# ...                                                 ...
# 2409                                                  😂
# 2410  Siapapun presidennya, tolong, supaya makmur jg...
# 2411  Gila ngeliat muka dan perawakannya prabowo set...
# 2412                 PRIHATIN. PEMILU PENUH KECURANGAN.
# 2413  Sdm rendahan yg pilih lu wo milih karna dsogok...
#
# [2414 rows x 3 columns]

# %%
data_instagram.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2414 entries, 0 to 2413
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   instagram_account  2410 non-null   object
#  1   username           2410 non-null   object
#  2   comment            2394 non-null   object
# dtypes: object(3)
# memory usage: 56.7+ KB

# %%
# Menyimpan dataset
data_instagram.to_csv('dataset_instagram.csv', index=False)

# %% [markdown]
# #MERGE ALL DATASET

# %%
#upload dataset

data_x = pd.read_csv('/content/dataset_x.csv')
data_youtube = pd.read_csv('/content/dataset_youtube.csv')
data_instagram = pd.read_csv('/content/dataset_instagram.csv')

# %% [markdown]
# dataset X

# %%
#baca tiap dataset
data_x
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0             1,79511E+18  Mon May 27 15:23:40 +0000 2024               0
# 1             1,79504E+18  Mon May 27 10:24:21 +0000 2024               0
# 2             1,79499E+18  Mon May 27 07:18:28 +0000 2024               0
# 3             1,79491E+18  Mon May 27 04:36:40 +0000 2024               1
# 4             1,79473E+18  Sun May 26 22:53:23 +0000 2024               0
# ...                   ...                             ...             ...
# 1981  1770464478678884424  Wed Mar 20 22:32:50 +0000 2024               0
# 1982  1770315277877608776  Wed Mar 20 21:52:04 +0000 2024               0
# 1983  1770479285255696720  Wed Mar 20 19:59:09 +0000 2024               0
# 1984  1770497099207205325  Wed Mar 20 17:06:17 +0000 2024               0
# 1985  1770494193645047813  Wed Mar 20 16:54:44 +0000 2024              75
#
#                                               full_text               id_str  \
# 0          Ini implikasi masih jadi presiden taun depan          1,79511E+18
# 1     Sepertinya setelah pelantikan presiden dunia m...          1,79504E+18
# 2     Menyatakan oposisi setelah pelantikan presiden...          1,79499E+18
# 3     Sampai saat ini kondisi politik dan pertumbuha...          1,79495E+18
# 4     pelantikan presiden baru kalo ada kebijakannya...          1,79486E+18
# ...                                                 ...                  ...
# 1981  @mas_veel 2019 juga sama. Di wrg bakso anak kc...  1770579280566862111
# 1982  @mapedos01 Terserah apa katamu bang. Toh besok...  1770569019541840257
# 1983  @aniesbaswedan Intinya yg kalah bakal banyak d...  1770540601421021263
# 1984  Selamat atas penetapan Prabowo Subianto dan Gi...  1770497099207205325
# 1985  Semoga sehat jiwa raga ya pak sampe pelantikan...  1770494193645047813
#
#                                             image_url in_reply_to_screen_name  \
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN          DedynurPalakka
# 4                                                 NaN                  jogmfs
# ...                                               ...                     ...
# 1981                                              NaN                mas_veel
# 1982                                              NaN               mapedos01
# 1983                                              NaN           aniesbaswedan
# 1984  https://pbs.twimg.com/media/GJIRuO_aQAA27PK.jpg                     NaN
# 1985                                              NaN                     NaN
#
#      lang       location  quote_count  reply_count  retweet_count  \
# 0      in  Hindia Widodo            0            0              0
# 1      in   Dalem Sumur             0            0              0
# 2      in            NaN            0            0              0
# 3      in            NaN            0            0              0
# 4      in            NaN            0            1              0
# ...   ...            ...          ...          ...            ...
# 1981   in            NaN            0            0              0
# 1982   in            NaN            0            0              0
# 1983   in            NaN            0            0              0
# 1984   in      Indonesia            0            0              0
# 1985   in            NaN            7          103             16
#
#                                               tweet_url          user_id_str  \
# 0     https://x.com/und_cuckoosnest/status/179511364...          1,76091E+18
# 1     https://x.com/KangSuparmin/status/179503832372...           2556225356
# 2     https://x.com/CantikSeorang/status/17949915476...          1,73631E+18
# 3     https://x.com/R19cakra/status/1794950828601880779          1,73096E+18
# 4     https://x.com/daunkaca/status/1794864436584575474          1,24393E+18
# ...                                                 ...                  ...
# 1981  https://x.com/rakabuning/status/17705792805668...  1724707826365599744
# 1982  https://x.com/MhasnanN/status/1770569019541840257  1105357185012269056
# 1983  https://x.com/Paranoi47692947/status/177054060...  1750860870278856704
# 1984  https://x.com/SudieZaluchu/status/177049709920...  1026051379096301568
# 1985  https://x.com/are_inismyname/status/1770494193...  1152447574411902977
#
#              username
# 0     und_cuckoosnest
# 1        KangSuparmin
# 2       CantikSeorang
# 3            R19cakra
# 4            daunkaca
# ...               ...
# 1981       rakabuning
# 1982         MhasnanN
# 1983  Paranoi47692947
# 1984     SudieZaluchu
# 1985   are_inismyname
#
# [1986 rows x 15 columns]

# %%
data_x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   conversation_id_str      1986 non-null   object
#  1   created_at               1986 non-null   object
#  2   favorite_count           1986 non-null   int64
#  3   full_text                1986 non-null   object
#  4   id_str                   1986 non-null   object
#  5   image_url                439 non-null    object
#  6   in_reply_to_screen_name  1033 non-null   object
#  7   lang                     1986 non-null   object
#  8   location                 989 non-null    object
#  9   quote_count              1986 non-null   int64
#  10  reply_count              1986 non-null   int64
#  11  retweet_count            1986 non-null   int64
#  12  tweet_url                1986 non-null   object
#  13  user_id_str              1986 non-null   object
#  14  username                 1986 non-null   object
# dtypes: int64(4), object(11)
# memory usage: 232.9+ KB

# %%
#menyisakan bagian tweet dari data X , yaitu kolom full_text
data_x = data_x[['full_text']]
data_x
# Out:
#                                               full_text
# 0          Ini implikasi masih jadi presiden taun depan
# 1     Sepertinya setelah pelantikan presiden dunia m...
# 2     Menyatakan oposisi setelah pelantikan presiden...
# 3     Sampai saat ini kondisi politik dan pertumbuha...
# 4     pelantikan presiden baru kalo ada kebijakannya...
# ...                                                 ...
# 1981  @mas_veel 2019 juga sama. Di wrg bakso anak kc...
# 1982  @mapedos01 Terserah apa katamu bang. Toh besok...
# 1983  @aniesbaswedan Intinya yg kalah bakal banyak d...
# 1984  Selamat atas penetapan Prabowo Subianto dan Gi...
# 1985  Semoga sehat jiwa raga ya pak sampe pelantikan...
#
# [1986 rows x 1 columns]

# %% [markdown]
# dataset Youtube

# %%
data_youtube
# Out:
#                publishedAt      authorDisplayName  \
# 0     2024-04-23T22:46:35Z  @mranggenmranghen9769
# 1     2024-04-23T16:28:37Z       @user-uu5qx4lo1n
# 2     2024-04-22T13:14:02Z          @porwanti8152
# 3     2024-04-20T16:17:07Z    @endangsulastri9372
# 4     2024-04-19T12:02:11Z               @HanilNi
# ...                    ...                    ...
# 2696  2024-03-02T11:28:09Z     @ramsesnababan1071
# 2697  2024-03-02T11:24:42Z      @RahmadTour-ns9zk
# 2698  2024-03-02T11:23:57Z      @RahmadTour-ns9zk
# 2699  2024-03-02T11:23:35Z      @RahmadTour-ns9zk
# 2700  2024-03-02T11:22:42Z    @candrapurnawan8353
#
#                                             textDisplay  like_count  likeCount
# 0                               Semoga amanah ya bapak❤         0.0        NaN
# 1                                                Curang         0.0        NaN
# 2                                      Prabowo sombong😡         0.0        NaN
# 3     Saya berdoa supaya apa yg dikatakan Prabowo te...         0.0        NaN
# 4     Awas awas hati hati kata jokowi, prabowo hati ...         0.0        NaN
# ...                                                 ...         ...        ...
# 2696       Jgn banyak omong Takut salah, bukti yg perlu         NaN        0.0
# 2697                      MIMMMMMMPIIIIIII<br>😂😂😂😂😂😂😂😂😂         NaN        0.0
# 2698                                           HA HA HA         NaN        0.0
# 2699                                              😂😂😂😂😂         NaN        0.0
# 2700  Kalau Nasdem masuk pemerintah. Apa metro masih...         NaN        3.0
#
# [2701 rows x 5 columns]

# %%
data_youtube.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2701 entries, 0 to 2700
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   publishedAt        2701 non-null   object
#  1   authorDisplayName  2701 non-null   object
#  2   textDisplay        2700 non-null   object
#  3   like_count         245 non-null    float64
#  4   likeCount          2454 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 105.6+ KB

# %%
#menyisakan bagian comment dari data youtube , yaitu kolom textDisplay
data_youtube = data_youtube[['textDisplay']]
data_youtube
# Out:
#                                             textDisplay
# 0                               Semoga amanah ya bapak❤
# 1                                                Curang
# 2                                      Prabowo sombong😡
# 3     Saya berdoa supaya apa yg dikatakan Prabowo te...
# 4     Awas awas hati hati kata jokowi, prabowo hati ...
# ...                                                 ...
# 2696       Jgn banyak omong Takut salah, bukti yg perlu
# 2697                      MIMMMMMMPIIIIIII<br>😂😂😂😂😂😂😂😂😂
# 2698                                           HA HA HA
# 2699                                              😂😂😂😂😂
# 2700  Kalau Nasdem masuk pemerintah. Apa metro masih...
#
# [2701 rows x 1 columns]

# %% [markdown]
# dataset instagram

# %%
data_instagram
# Out:
#                                       instagram_account  \
# 0                  https://www.instagram.com/sybila4239
# 1                  https://www.instagram.com/2person_30
# 2                https://www.instagram.com/ersita_megaa
# 3                  https://www.instagram.com/cannberryy
# 4             https://www.instagram.com/supriabdullah97
# ...                                                 ...
# 2409           https://www.instagram.com/riirin.gobell/
# 2410  https://www.instagram.com/ghania.entertainment...
# 2411            https://www.instagram.com/wibowo.track/
# 2412          https://www.instagram.com/iwan.muharam99/
# 2413        https://www.instagram.com/rianaldiansyah46/
#
#                      username  \
# 0                  sybila4239
# 1                  2person_30
# 2                ersita_megaa
# 3                  cannberryy
# 4             supriabdullah97
# ...                       ...
# 2409            riirin.gobell
# 2410  ghania.entertainment.wo
# 2411             wibowo.track
# 2412           iwan.muharam99
# 2413         rianaldiansyah46
#
#                                                 comment
# 0     Jangan lama2 pak, gak sabar liat bapak, jadi p...
# 1     alhamdulillah pak prabowo ????, insya allah de...
# 2                                  Bapakkk selamat yaa
# 3                                   Selamat Pak Prabowo
# 4     Mari di bulan Puasa ini berdoa semoga Pemimpin...
# ...                                                 ...
# 2409                                                  😂
# 2410  Siapapun presidennya, tolong, supaya makmur jg...
# 2411  Gila ngeliat muka dan perawakannya prabowo set...
# 2412                 PRIHATIN. PEMILU PENUH KECURANGAN.
# 2413  Sdm rendahan yg pilih lu wo milih karna dsogok...
#
# [2414 rows x 3 columns]

# %%
data_instagram.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2414 entries, 0 to 2413
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   instagram_account  2410 non-null   object
#  1   username           2410 non-null   object
#  2   comment            2394 non-null   object
# dtypes: object(3)
# memory usage: 56.7+ KB

# %%
#menyisakan bagian comment dari data instagram , yaitu kolom comment
data_instagram = data_instagram[['comment']]
data_instagram
# Out:
#                                                 comment
# 0     Jangan lama2 pak, gak sabar liat bapak, jadi p...
# 1     alhamdulillah pak prabowo ????, insya allah de...
# 2                                  Bapakkk selamat yaa
# 3                                   Selamat Pak Prabowo
# 4     Mari di bulan Puasa ini berdoa semoga Pemimpin...
# ...                                                 ...
# 2409                                                  😂
# 2410  Siapapun presidennya, tolong, supaya makmur jg...
# 2411  Gila ngeliat muka dan perawakannya prabowo set...
# 2412                 PRIHATIN. PEMILU PENUH KECURANGAN.
# 2413  Sdm rendahan yg pilih lu wo milih karna dsogok...
#
# [2414 rows x 1 columns]

# %% [markdown]
# Menggabungkan seluruh data

# %%
Dataset = pd.concat([data_x,
                     data_youtube.rename(columns={'textDisplay': 'full_text'}),
                     data_instagram.rename(columns={'comment': 'full_text'})], ignore_index=True)

# %%
Dataset
# Out:
#                                               full_text
# 0          Ini implikasi masih jadi presiden taun depan
# 1     Sepertinya setelah pelantikan presiden dunia m...
# 2     Menyatakan oposisi setelah pelantikan presiden...
# 3     Sampai saat ini kondisi politik dan pertumbuha...
# 4     pelantikan presiden baru kalo ada kebijakannya...
# ...                                                 ...
# 7096                                                  😂
# 7097  Siapapun presidennya, tolong, supaya makmur jg...
# 7098  Gila ngeliat muka dan perawakannya prabowo set...
# 7099                 PRIHATIN. PEMILU PENUH KECURANGAN.
# 7100  Sdm rendahan yg pilih lu wo milih karna dsogok...
#
# [7101 rows x 1 columns]

# %%
#menghapus baris yang NaN dan mereset indeks
Dataset.dropna(inplace=True)
Dataset.reset_index(drop=True, inplace=True)
Dataset
# Out:
#                                               full_text
# 0          Ini implikasi masih jadi presiden taun depan
# 1     Sepertinya setelah pelantikan presiden dunia m...
# 2     Menyatakan oposisi setelah pelantikan presiden...
# 3     Sampai saat ini kondisi politik dan pertumbuha...
# 4     pelantikan presiden baru kalo ada kebijakannya...
# ...                                                 ...
# 7075                                                  😂
# 7076  Siapapun presidennya, tolong, supaya makmur jg...
# 7077  Gila ngeliat muka dan perawakannya prabowo set...
# 7078                 PRIHATIN. PEMILU PENUH KECURANGAN.
# 7079  Sdm rendahan yg pilih lu wo milih karna dsogok...
#
# [7080 rows x 1 columns]

# %% [markdown]
# #Menyimpan Keseluruhan Dataset

# %%
# Menyimpan dataset
Dataset.to_csv('Dataset.csv', index=False)
